# %% [markdown]
# ### 测试ISI

# %%
import matplotlib.pyplot as plt
import numpy as np
from numba import njit, prange
# 自定义函数
from import_fun import HH

# %%
dt = 0.01
method = 'euler'    # （"euler", "rk4"）
N = 1000

# %%
nodes = HH(N, method, dt)
nodes.params_nodes["Iex"] = 0.

Io = np.linspace(0, 100, N)

# %%
for i in range(100_00):
    nodes(Io)

nodes.record_spike_times = True
for i in range(1000_00):
    nodes(Io)

# %%
valid_spike_times = nodes.return_spike_times()

# %%
# valid_spike_times

# %%
isi = nodes.cal_isi()

# %%
isi.shape
# Out:
# (1000, 126)

# %%
plt.plot(Io, isi, 'o',  markersize=2, color="k")
plt.xlabel("Iex")
plt.ylabel("ISI")
plt.show()

# %%
cv = nodes.cal_cv()

# %%
plt.plot(Io, cv, 'o',  markersize=2, color="k")
plt.xlabel("Iex")
plt.ylabel("cv")
plt.show()
