# %% [markdown]
#  #### 测试 PRC 曲线(HH)

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from import_fun import Phase_Response_Curves
from import_fun import HH

# %%
node = HH()
node.params_nodes["Iex"] = 20.

# %%
PRCer = Phase_Response_Curves(node)
PRCer.g_syn = 0.2
prc = PRCer()

# %%
PRCer.plot_phase_shift()
fig = plt.gcf()
fig.suptitle("Phase Response Curves(HH)")
plt.show()

# %%
node = HH()
node.params_nodes["Iex"] = 20.
PRCer = Phase_Response_Curves(node)
PRCer.g_syn = 0.01
prc1 = PRCer()
in_phase = PRCer.in_phase

node = HH()
node.params_nodes["Iex"] = 20.
PRCer = Phase_Response_Curves(node)
PRCer.g_syn = 0.05
prc2 = PRCer()

node = HH()
node.params_nodes["Iex"] = 20.
PRCer = Phase_Response_Curves(node)
PRCer.g_syn = 0.1
prc3 = PRCer()

# %%
fig, axs = plt.subplots(1, layout='constrained')
axs.plot(in_phase, prc1)
axs.plot(in_phase, prc2)
axs.plot(in_phase, prc3)
plt.axhline(y=0.0, color='r', linestyle='--', lw=2)
fig = plt.gcf()
fig.suptitle("Phase Response Curves(HH)")
# Out:
# Text(0.5, 0.98, 'Phase Response Curves(HH)')

# %% [markdown]
# #### 使用脉冲输入方式，测试PRC

# %%
node = HH()
node.params_nodes["Iex"] = 20.

# %%
PRCer = Phase_Response_Curves(node, pulses=True)
PRCer.pulses_width = 1.
PRCer.g_syn = 0.2
prc = PRCer()

# %%
PRCer.plot_phase_shift()
fig = plt.gcf()
fig.suptitle("Phase Response Curves(HH)")
plt.show()

# %%
node = HH()
node.params_nodes["Iex"] = 20.
PRCer = Phase_Response_Curves(node, pulses=True)
PRCer.pulses_width = 1.
PRCer.g_syn = 0.01
prc1 = PRCer()
in_phase = PRCer.in_phase

node = HH()
node.params_nodes["Iex"] = 20.
PRCer = Phase_Response_Curves(node, pulses=True)
PRCer.pulses_width = 1.
PRCer.g_syn = 0.05
prc2 = PRCer()

node = HH()
node.params_nodes["Iex"] = 20.
PRCer = Phase_Response_Curves(node, pulses=True)
PRCer.pulses_width = 1.
PRCer.g_syn = 0.1
prc3 = PRCer()

# %%
fig, axs = plt.subplots(1, layout='constrained')
axs.plot(in_phase, prc1)
axs.plot(in_phase, prc2)
axs.plot(in_phase, prc3)
plt.axhline(y=0.0, color='r', linestyle='--', lw=2)
fig = plt.gcf()
fig.suptitle("Phase Response Curves(HH)")
# Out:
# Text(0.5, 0.98, 'Phase Response Curves(HH)')
