# %% [markdown]
#  #### 测试 PRC 的相位漂移(HH)

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from import_fun import phase_shift
from import_fun import HH

# %%
node = HH()
node.params_nodes["Iex"] = 20.

# %%
phi_shift = phase_shift(node, phase=[0.3])
phi_shift.g_syn = 0.2
phi_shift()

# %%
phi_shift.plot_phase_shift()
fig = plt.gcf()
fig.suptitle("phase shift(HH)")
plt.show()

# %%
node = HH()
node.params_nodes["Iex"] = 20.
phi_shift = phase_shift(node, phase=[0.4, 0.7])
phi_shift.g_syn = 0.2
phi_shift()

# %%
phi_shift.plot_phase_shift()
fig = plt.gcf()
fig.suptitle("phase shift(HH)")
plt.show()

# %% [markdown]
# #### 使用脉冲输入方式，测试相位漂移

# %%
node = HH()
node.params_nodes["Iex"] = 20.

# %%
phi_shift = phase_shift(node, phase=[0.4, 0.7], pulses=True)
phi_shift.pulses_width = 1.
phi_shift.g_syn = 0.2
phi_shift()

# %%
phi_shift.plot_phase_shift()
fig = plt.gcf()
fig.suptitle("phase shift(HH)")
plt.show()
